# %% [markdown]
# <a href="https://colab.research.google.com/github/clecio2022dev/DataScience/blob/main/Atividade_sala_26.11.2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
plt.style.use('seaborn-talk')
dados = pd.read_csv('/Dados-Pesquisa.csv')

# %%
dados.head(1-2)
# Out:
#        Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0     28.0               0.0             NaN                   NaN
# 1     22.0               0.0             NaN                   NaN
# 2     19.0               0.0             NaN                   NaN
# 3     26.0               0.0             NaN                   NaN
# 4     20.0               0.0             NaN                   NaN
# ...    ...               ...             ...                   ...
# 6280  31.0               0.0             NaN                   NaN
# 6281  47.0               0.0             NaN                   NaN
# 6282  26.0               1.0             1.0                   0.0
# 6283  30.0               0.0             NaN                   NaN
# 6284  48.0               0.0             NaN                   NaN
#
#       BootcampLoanYesNo  BootcampMonthsAgo   BootcampName  BootcampPostSalary  \
# 0                   NaN                NaN            NaN                 NaN
# ...

# %%
dados.shape
# Out:
# (6286, 113)

# %%
dados.columns.to_list()
# Out:
# ['Age',
#  'AttendedBootcamp',
#  'BootcampFinish',
#  'BootcampFullJobAfter',
#  'BootcampLoanYesNo',
#  'BootcampMonthsAgo',
#  'BootcampName',
#  'BootcampPostSalary',
#  'BootcampRecommend',
#  'ChildrenNumber',
#  'CityPopulation',
#  'CodeEventBootcamp',
#  'CodeEventCoffee',
#  'CodeEventConferences',
#  'CodeEventDjangoGirls',
#  'CodeEventGameJam',
#  'CodeEventGirlDev',
#  'CodeEventHackathons',
#  'CodeEventMeetup',
#  'CodeEventNodeSchool',
#  'CodeEventNone',
#  'CodeEventOther',
#  'CodeEventRailsBridge',
#  'CodeEventRailsGirls',
#  'CodeEventStartUpWknd',
#  'CodeEventWomenCode',
#  'CodeEventWorkshop',
#  'CommuteTime',
#  'CountryCitizen',
#  'CountryLive',
#  'EmploymentField',
#  'EmploymentFieldOther',
#  'EmploymentStatus',
#  'EmploymentStatusOther',
#  'ExpectedEarning',
#  'FinanciallySupporting',
#  'Gender',
#  'HasChildren',
#  'HasDebt',
#  'HasFinancialDependents',
#  'HasHighSpdInternet',
#  'HasHomeMortgage',
#  'HasServedInMilitary',
# ...

# %%
df2=dados.copy()

# %%
df2.shape
# Out:
# (6286, 113)

# %%
dados.isna().sum().sum()
# Out:
# 459931

# %%
dados.dropna(subset=['Age'], inplace=True)

# %%
dados.isna().sum()
# Out:
# Age                        0
# AttendedBootcamp          41
# BootcampFinish          5793
# BootcampFullJobAfter    5908
# BootcampLoanYesNo       5794
#                         ...
# ResourceW3Schools       6090
# ResourceYouTube         6077
# SchoolDegree              45
# SchoolMajor             2298
# StudentDebtOwe          4478
# Length: 113, dtype: int64

# %%
dados.isna().sum().sum()
# Out:
# 446346

# %%
print('A base de dado apresenta {} linhas e {} colunas'.format(dados.shape[0],dados.shape[1]))
# Out:
# A base de dado apresenta 6128 linhas e 113 colunas

# %%
dados.dtypes.value_counts()
# Out:
# float64    87
# object     26
# dtype: int64

# %%
dados
# Out:
#        Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0     28.0               0.0             NaN                   NaN
# 1     22.0               0.0             NaN                   NaN
# 2     19.0               0.0             NaN                   NaN
# 3     26.0               0.0             NaN                   NaN
# 4     20.0               0.0             NaN                   NaN
# ...    ...               ...             ...                   ...
# 6281  47.0               0.0             NaN                   NaN
# 6282  26.0               1.0             1.0                   0.0
# 6283  30.0               0.0             NaN                   NaN
# 6284  48.0               0.0             NaN                   NaN
# 6285  30.0               0.0             NaN                   NaN
#
#       BootcampLoanYesNo  BootcampMonthsAgo   BootcampName  BootcampPostSalary  \
# 0                   NaN                NaN            NaN                 NaN
# ...

# %%
#Criando um novo Data Frame apenas com as colunas que queremos:
#dados = [['Age','Gender','JobPref','JobRoleInterest','EmploymentField','JobRelocateYesNo','HoursLearning','MoneyForLearning']]
#dados.
dados
# Out:
#        Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0     28.0               0.0             NaN                   NaN
# 1     22.0               0.0             NaN                   NaN
# 2     19.0               0.0             NaN                   NaN
# 3     26.0               0.0             NaN                   NaN
# 4     20.0               0.0             NaN                   NaN
# ...    ...               ...             ...                   ...
# 6281  47.0               0.0             NaN                   NaN
# 6282  26.0               1.0             1.0                   0.0
# 6283  30.0               0.0             NaN                   NaN
# 6284  48.0               0.0             NaN                   NaN
# 6285  30.0               0.0             NaN                   NaN
#
#       BootcampLoanYesNo  BootcampMonthsAgo   BootcampName  BootcampPostSalary  \
# 0                   NaN                NaN            NaN                 NaN
# ...

# %%
dados.describe(include ='O')
# Out:
#             BootcampName       CityPopulation            CountryCitizen  \
# count                324                 6068                      6073
# unique                76                    3                       136
# top     General Assembly  more than 1 million  United States of America
# freq                  30                 2408                      2857
#
#                      CountryLive              EmploymentField  \
# count                       6049                         3297
# unique                       133                           15
# top     United States of America  software development and IT
# freq                        2996                         1777
#
#        EmploymentFieldOther    EmploymentStatus EmploymentStatusOther Gender  \
# count                   455                5714                   322   6108
# unique                  341                  10                   159      5
# ...

# %%
dados.shape
# Out:
# (6128, 113)

# %%
#usando Loc 

dados.loc[dados['Age']> 30]
# Out:
#        Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 5     34.0               0.0             NaN                   NaN
# 7     35.0               0.0             NaN                   NaN
# 8     33.0               0.0             NaN                   NaN
# 9     33.0               0.0             NaN                   NaN
# 10    57.0               0.0             NaN                   NaN
# ...    ...               ...             ...                   ...
# 6266  44.0               0.0             NaN                   NaN
# 6267  42.0               0.0             NaN                   NaN
# 6280  31.0               0.0             NaN                   NaN
# 6281  47.0               0.0             NaN                   NaN
# 6284  48.0               0.0             NaN                   NaN
#
#       BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 5                   NaN                NaN          NaN                 NaN
# ...

# %%
dados['Age'].unique()
# Out:
# array([28., 22., 19., 26., 20., 34., 23., 35., 33., 57., 27., 47., 37.,
#        31., 29., 30., 32., 25., 44., 21., 24., 18., 39., 41., 43., 36.,
#        40., 38., 16., 46., 15., 14., 50., 49., 45., 55., 51., 17., 53.,
#        52., 48., 56., 42., 54., 58., 65., 59., 75., 61., 80., 62., 60.,
#        66., 12., 11., 13., 63., 64., 70., 73., 69., 71., 68.])

# %%
dados.Age.unique()
# Out:
# array([28., 22., 19., 26., 20., 34., 23., 35., 33., 57., 27., 47., 37.,
#        31., 29., 30., 32., 25., 44., 21., 24., 18., 39., 41., 43., 36.,
#        40., 38., 16., 46., 15., 14., 50., 49., 45., 55., 51., 17., 53.,
#        52., 48., 56., 42., 54., 58., 65., 59., 75., 61., 80., 62., 60.,
#        66., 12., 11., 13., 63., 64., 70., 73., 69., 71., 68.])

# %%
#Qual é a Distribuição de idade dos participantes da pesquisa?
#Variável Age
idade = dados.Age #dados['Age']

#Histograma
plt.hist(idade, label="idades", color='green')
plt.title('Distribuição por Idades')
plt.xlabel('Idades')
plt.ylabel('Quantidade')
plt.legend()
plt.grid(True)
plt.show()

# %%
tipos_de_genero = dados.Gender

# %%
dados.Gender.value_counts()

# %%
tipos_de_genero.columns.name = 'Tipo'

# %%
tipos_de_genero.iloc[0]

# %%
feminino = tipos_de_genero.loc['female']
feminino

# %%
total_genero = dados.Gender.value_counts().sum()
total_genero

# %%
#selecionando linha female e tirando a porcentagem
fem = (feminino/total_genero*100)

# %%
genero = dados.Gender.value_counts()
genero

# %%
interesses = dados.JobRoleInterest.value_counts()
interesses.plot(kind = 'bar')

# %%
#grafico de pizza
interesses = dados.JobRoleInterest.value_counts()
plt.pie(interesses, startangle=90)
plt.legend(interesses.index, bbox_to_anchor=(1,0.9))
plt.show()
